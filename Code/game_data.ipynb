# %% [markdown]
# Steam 인디게임 개발자들의 게임판매량 예측
# ================
# 한국산업기술대학교 게임공학과 2012180012 김찬현
# -----------------------------
#  (2017년 6월 28일 작성)

# %% [markdown]
# # 1 서론
# 본 주제를 연구하게 된 계기는 인디개발자들은 대기업 게임기업들보다 적게 수익을 낼까라는 단순한 의문에서 비롯하게 된 개인 연구주제이다.연구 주제는 1,2,3차로 주제가 나뉘어진다.

# %% [markdown]
# *1 차: 스팀에서 얻은 고객들의 게임평가 코멘트수를 기반으로한 게임다운로드 수 예측, Steamspy에서 제공하는 OWNERS데이터에서 얻은 최저 값을, 고객들이 실제로 다운로드 받은 값이라고 가정하여 결과 검정 모델 생성*

# %% [markdown]
# *2 차: 게임개발자들이 게임을 출시하기 이전에 유튜브로 자신들이 만든 게임들 홍보 및, 게임제작을 처음 시작한 날짜(게임회사는 설립날짜)를 기반으로 예측하는 게임다운로드 수 예측*

# %% [markdown]
# *3 차: 머신러닝을 활용하여 각 게임마다 사람들이 만족했던 부분을 자연어처리(NTLK방식)를 이용하여 긍정적으로 언급한 단어들(ex: 배경음이 좋다, 그래픽이 좋다)에 대해 각각 가중치를 부여하여, 순위가 가장 높이 언급된 게임요소들을 정렬하여 게임개발자들이 더욱 신경써야 하는부분을 도출 *

# %% [markdown]
# # 2. _들어가기 앞서서_

# %% [markdown]
# - 필자는 본 연구를 시행하기 앞서서 데이터를 처음 모은 시점이 2017년05월09일이다.프로그래밍 언어는 _파이썬_을 이용하였다.기본적으로 Pandas 를 이용하며 데이터는 하루에 15개씩 모아서, 모은 데이터들은 csv형식으로 저장한다. 2017년 7월30일날 1000개의 데이터가 모아질 예정이고, 이렇게 모은 데이터를 기반으로 데이터분석을 할 예정이다.

# %% [markdown]
#  - selenium을 이용한 웹 크롤링 방식을 사용하여 데이터를 수집할 생각이였으나 이는 아래와 같은 사유로 불가함을 알고 직접 데이터를 수집하기 시작하였다.

# %% [markdown]
#     *1. Steam에서 제공하는 Release date(스팀에서의 출시일자)값이 잘못 나와있는 경우가 있다. 이는 잘못된 데이터를 수집하게 하는 원인이 된다.
#     *2. 구하고자하는 column의 값들(ex: 게임엔진, 각 게임회사들의 설립날짜 및 개인개발자들의 게임초기제작날짜, 유튜브에 올라온 초기 업로드 홍보영상날짜)을 찾기위해서는 많은 검색작업이 필요하며 수 많은 사이트를 둘러봐야하는데, 크롤링으로는 불가하다는 판단을 내렸다.

# %% [markdown]
# - 현재 2017년 6월28일 기준으로 모인 데이터는 총 370개 (추가업데이트 필요)

# %% [markdown]
# - 데이터 1000개는 모집단으로 턱없이 부족한 갯수임을 인지하고 있지만, 실질적으로 데이터를 만 개 단위까지 모으기에는 졸업작품과 병행하기에 시간이 부족하기 때문에, 머신러닝을 이용한 회귀분석과 자연어 처리를 통한 고객들의 반응 평가에서 가장 긍정적으로 뽑힌 단어들의 순위를 인공지능이 알려주는 것에 초점을 맞추어 연구과제를 실시할 예정이다.

# %% [markdown]
# - 게임데이터는 내년 2018년 8월까지 만 개를 모을 생각이며, 졸업작품으로 써가 아닌 개인 연구과제로 계속 진행해 나갈 예정이다.

# %% [markdown]
# ###  Columns 소개

# %% [markdown]
# - 게임이름
# - 데이터 조사날짜
# - 스팀 리뷰 수
# - 스팀외 리뷰 수
# - 스팀발매 일자
# - 평점
# - 장르
# - 장르2 (차후 추가해야함)
# - 사용된 게임엔진
# - 개발자 or 게임회사 이름
# - 개발자 초기 게임 제작 날짜 or 게임회사 초기 설립날짜
# - 개발자 or 게임회사의 존속기간
# - 게임의 View방식 (2D,3D)
# - 게임 출시 전에 유튜브에 올린 초기 게임 홍보영상(게임 제작과정 업로드 포함)
# - Owner Value (유저들이 게임을 다운로드 받은 횟수 라고 가정하는 값)

# %% [markdown]
# -------------------------------------------------
# 아래는 파이썬 코드부분입니다.
#
# -------------------------------------------------

# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./gamedevelopinfo.csv')

# %% [markdown]
# ###### '비고' 열부터 끝까지 지우기 (현재 데이터가 다 채워지지않아서 의미가없음) - 6.28일기준

# %%
df = df.drop(df.loc[:,'비고':],axis=1)

# %%
df=df.dropna(thresh=3)
df.head()
# Out:
#                                     게임제목        조사날짜   스팀리뷰수 스팀외리뷰수  \
# 0                       Little Nightmare  2017-05-09  1196.0    331
# 1  Bendy and the Ink machine Chapter one  2017-05-09    29.0   1307
# 2                        The SEXY BRUTAL  2017-05-09   214.0     14
# 3  Bendy and the Ink machine Chapter two  2017-05-09    89.0      7
# 4               Ori and the Blind Forest  2017-05-09  4734.0    713
#
#         스팀발매일  평점       가격   엔진플랫폼    장르     유튜브등록날짜               회사이름  \
# 0  2017-04-28   9  25800.0  Unreal    호러  2015-02-25    Tarsier Studios
# 1  2017-04-27   9      0.0   Unity    호러  2016-05-11    TheMeatly Games
# 2  2017-04-11   9  21000.0   Unity  어드벤쳐  2016-08-19      Tequila Works
# 3  2017-04-27   9   6500.0   Unity    호러  2016-05-11    TheMeatly Games
# 4  2015-03-11  10  10500.0   Unity    액션  2014-06-09  Moon studios Gmbh
#
#   회사초창기설립날짜 회사존속기간
# 0     2004년    13년
# 1  2017년 1월    4개월
# 2     2009년     8년
# 3  2017년 1월    4개월
# 4     2010년     7년

# %%
EngineName=df['엔진플랫폼'].value_counts().drop(['질문중-steam','질문중-youtube','질문해야함','질문중 -steam','질문중 -Steam','질문해야함-누가 질문해놨음','질문중 -Youtube']).index.tolist()

# %%
EngineCount=df['엔진플랫폼'].value_counts().drop(['질문중-steam','질문중-youtube','질문해야함','질문중 -steam','질문중 -Steam','질문해야함-누가 질문해놨음','질문중 -Youtube'])

# %%
plt.figure(figsize=(30,40))
ax=sns.barplot(EngineCount.index,EngineCount.values)
ax=ax.set_xticklabels(EngineName,rotation=80,fontsize=20)
ax=plt.rc('ytick',labelsize=20)
plt.show()

# %%
df['평점']=pd.to_numeric(df['평점'])
df.groupby(['장르'])['평점'].mean()
# Out:
# 장르
# RPG       8.000000
# VR        7.937500
# 고어        9.000000
# 시뮬레이션     8.666667
# 아케이드      8.000000
# 액션        8.032258
# 어드벤쳐      8.132812
# 전략        8.000000
# 캐쥬얼       7.639344
# 캐쥬얼,퍼즐    5.500000
# 퍼즐        8.333333
# 호러        7.909091
# Name: 평점, dtype: float64

# %%
import datetime
from dateutil.parser import parse as parse_date

# %%
dataTime_list=[]
#datalist.append(parse_date(df['조사날짜'][0]))

# %%
#EngineName=df['엔진플랫폼'].value_counts().index.tolist()
length = len(df['조사날짜'].value_counts().index.tolist())
df['조사날짜'].value_counts().index.tolist()
# Out:
# ['2017-06-14',
#  '2017-06-17',
#  '2017-06-07',
#  '2017-06-18',
#  '2017-06-13',
#  '2017-06-26',
#  '2017-06-20',
#  '2017-06-11',
#  '2017-06-19',
#  '2017-06-15',
#  '2017-06-16',
#  '2017-06-23',
#  '2017-06-22',
#  '2017-06-25',
#  '2017-05-09',
#  '2017-06-10',
#  '2017-06-08',
#  '2017-05-13',
#  '2017-05-24',
#  '2017-05-25',
#  '2017-05-27',
#  '2017-06-04',
#  '2017-05-30',
#  '2017-05-29',
#  '2017-05-10',
#  '2017-05-28',
#  '2017-06-01',
#  '2017-06-03',
#  '2017-05-22',
#  '2017-06-06',
#  '2017-06-05',
#  '2017-05-31',
#  '2017-05-14',
#  '2017-06-09',
#  '2017-05-20',
#  '2017-06-24',
#  '2017-06-21']

# %%
for i,v in enumerate(df['조사날짜'].value_counts().index.tolist()):
    dataTime_list.append(parse_date(v))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-e1678b72c149> in <module>()
#       1 for i,v in enumerate(df['조사날짜'].value_counts().index.tolist()):
# ----> 2     dataTime_list.append(parse_date(v))
#
# NameError: name 'parse_date' is not defined

# %%
dataTime_list.sort()

# %%
dataTime_list
# Out:
# [datetime.datetime(2017, 5, 9, 0, 0),
#  datetime.datetime(2017, 5, 10, 0, 0),
#  datetime.datetime(2017, 5, 13, 0, 0),
#  datetime.datetime(2017, 5, 14, 0, 0),
#  datetime.datetime(2017, 5, 20, 0, 0),
#  datetime.datetime(2017, 5, 22, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2017, 5, 25, 0, 0),
#  datetime.datetime(2017, 5, 27, 0, 0),
#  datetime.datetime(2017, 5, 28, 0, 0),
#  datetime.datetime(2017, 5, 29, 0, 0),
#  datetime.datetime(2017, 5, 30, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2017, 6, 1, 0, 0),
#  datetime.datetime(2017, 6, 3, 0, 0),
#  datetime.datetime(2017, 6, 4, 0, 0),
#  datetime.datetime(2017, 6, 5, 0, 0),
#  datetime.datetime(2017, 6, 6, 0, 0),
#  datetime.datetime(2017, 6, 7, 0, 0),
#  datetime.datetime(2017, 6, 8, 0, 0),
#  datetime.datetime(2017, 6, 9, 0, 0),
#  datetime.datetime(2017, 6, 10, 0, 0),
#  datetime.datetime(2017, 6, 11, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2017, 6, 14, 0, 0)]

# %%
df.groupby('조사날짜')['유튜브등록날짜'].describe()
# Out:
#            count unique         top freq
# 조사날짜
# 2017-05-09    11     10  2016-05-11    2
# 2017-05-10     5      5  2015-03-02    1
# 2017-05-13     8      8  2017-04-26    1
# 2017-05-14     5      5  2010-05-10    1
# 2017-05-20     4      4  2017-01-26    1
# 2017-05-22     5      5  2016-08-22    1
# 2017-05-24     6      6  2016-08-26    1
# 2017-05-25     5      5  2016-03-16    1
# 2017-05-27     5      5  2017-02-25    1
# 2017-05-28     5      5  2016-08-11    1
# 2017-05-29     5      4  2017-01-10    2
# 2017-05-30     5      5  2013-07-17    1
# 2017-05-31     5      5  2016-04-19    1
# 2017-06-01     5      5  2016-09-08    1
# 2017-06-03     5      5  2016-02-16    1
# 2017-06-04     5      5  2016-04-25    1
# 2017-06-05     5      5  2016-12-25    1
# 2017-06-06     5      5  2016-11-23    1
# 2017-06-07    20     20  2013-02-20    1
# 2017-06-08    10     10  2016-10-17    1
# 2017-06-09     4      4  2017-05-29    1
# 2017-06-10    11     11  2016-06-15    1
# 2017-06-11    15     15  2016-09-25    1
# 2017-06-13    15     15  2016-05-02    1
# 2017-06-14    30     29  2016-04-30    2

# %%
df['조사날짜'].value_counts().index
# Out:
# Index(['2017-06-14', '2017-06-07', '2017-06-11', '2017-06-13', '2017-06-10',
#        '2017-05-09', '2017-06-08', '2017-05-13', '2017-05-24', '2017-06-03',
#        '2017-05-29', '2017-05-30', '2017-06-04', '2017-05-10', '2017-05-27',
#        '2017-05-28', '2017-05-31', '2017-06-06', '2017-06-01', '2017-05-14',
#        '2017-05-22', '2017-05-25', '2017-06-05', '2017-05-20', '2017-06-09'],
#       dtype='object')

# %%
between_Pubdate_UtubeRegister=[]
for index,row in df.iterrows():
    #if (parse_date(row['조사날짜']) - parse_date(row['유튜브등록날짜'])<0):
        #print(parse['조사날짜'])
    
    between_Pubdate_UtubeRegister.append((parse_date(row['스팀발매일']) - parse_date(row['유튜브등록날짜'])))

# %%
between_Pubdate_UtubeRegister
# Out:
# [datetime.timedelta(793),
#  datetime.timedelta(351),
#  datetime.timedelta(235),
#  datetime.timedelta(351),
#  datetime.timedelta(275),
#  datetime.timedelta(138),
#  datetime.timedelta(1015),
#  datetime.timedelta(1),
#  datetime.timedelta(-1),
#  datetime.timedelta(74),
#  datetime.timedelta(74),
#  datetime.timedelta(75),
#  datetime.timedelta(80),
#  datetime.timedelta(171),
#  datetime.timedelta(576),
#  datetime.timedelta(9),
#  datetime.timedelta(351),
#  datetime.timedelta(288),
#  datetime.timedelta(0),
#  datetime.timedelta(17),
#  datetime.timedelta(105),
#  datetime.timedelta(989),
#  datetime.timedelta(1123),
#  datetime.timedelta(26),
#  datetime.timedelta(307),
#  datetime.timedelta(1049),
#  datetime.timedelta(450),
#  datetime.timedelta(36),
#  datetime.timedelta(173),
#  datetime.timedelta(500),
#  datetime.timedelta(592),
#  datetime.timedelta(567),
#  datetime.timedelta(109),
#  datetime.timedelta(372),
#  datetime.timedelta(31),
#  datetime.timedelta(256),
#  datetime.timedelta(133),
#  datetime.timedelta(40),
#  datetime.timedelta(9),
#  datetime.timedelta(0),
#  datetime.timedelta(270),
#  datetime.timedelta(91),
#  datetime.timedelta(26),
#  datetime.timedelta(105),
#  datetime.timedelta(429),
#  datetime.timedelta(136),
#  datetime.timedelta(106),
#  datetime.timedelta(537),
#  datetime.timedelta(158),
#  datetime.timedelta(1005),
#  datetime.timedelta(91),
#  datetime.timedelta(253),
#  datetime.timedelta(995),
#  datetime.timedelta(198),
#  datetime.timedelta(197),
#  datetime.timedelta(545),
#  datetime.timedelta(400),
#  datetime.timedelta(225),
#  datetime.timedelta(870),
#  datetime.timedelta(45),
#  datetime.timedelta(28),
#  datetime.timedelta(30),
#  datetime.timedelta(193),
#  datetime.timedelta(0),
#  datetime.timedelta(873),
#  datetime.timedelta(15),
#  datetime.timedelta(1213),
#  datetime.timedelta(53),
#  datetime.timedelta(76),
#  datetime.timedelta(331),
#  datetime.timedelta(272),
#  datetime.timedelta(807),
#  datetime.timedelta(114),
#  datetime.timedelta(190),
#  datetime.timedelta(364),
#  datetime.timedelta(266),
#  datetime.timedelta(881),
#  datetime.timedelta(637),
#  datetime.timedelta(6),
#  datetime.timedelta(472),
#  datetime.timedelta(7),
#  datetime.timedelta(236),
#  datetime.timedelta(1221),
#  datetime.timedelta(56),
#  datetime.timedelta(1557),
#  datetime.timedelta(114),
#  datetime.timedelta(371),
#  datetime.timedelta(784),
#  datetime.timedelta(41),
#  datetime.timedelta(145),
#  datetime.timedelta(-3),
#  datetime.timedelta(38),
#  datetime.timedelta(0),
#  datetime.timedelta(389),
#  datetime.timedelta(472),
#  datetime.timedelta(-4),
#  datetime.timedelta(32),
#  datetime.timedelta(9),
#  datetime.timedelta(55),
#  datetime.timedelta(32),
#  datetime.timedelta(81),
#  datetime.timedelta(24),
#  datetime.timedelta(1070),
#  datetime.timedelta(635),
#  datetime.timedelta(21),
#  datetime.timedelta(170),
#  datetime.timedelta(292),
#  datetime.timedelta(181),
#  datetime.timedelta(1),
#  datetime.timedelta(5),
#  datetime.timedelta(443),
#  datetime.timedelta(658),
#  datetime.timedelta(261),
#  datetime.timedelta(62),
#  datetime.timedelta(273),
#  datetime.timedelta(399),
#  datetime.timedelta(113),
#  datetime.timedelta(30),
#  datetime.timedelta(464),
#  datetime.timedelta(91),
#  datetime.timedelta(32),
#  datetime.timedelta(29),
#  datetime.timedelta(42),
#  datetime.timedelta(542),
#  datetime.timedelta(285),
#  datetime.timedelta(43),
#  datetime.timedelta(888),
#  datetime.timedelta(15),
#  datetime.timedelta(1),
#  datetime.timedelta(10),
#  datetime.timedelta(977),
#  datetime.timedelta(371),
#  datetime.timedelta(1007),
#  datetime.timedelta(317),
#  datetime.timedelta(698),
#  datetime.timedelta(-2),
#  datetime.timedelta(-3),
#  datetime.timedelta(172),
#  datetime.timedelta(468),
#  datetime.timedelta(50),
#  datetime.timedelta(67),
#  datetime.timedelta(42),
#  datetime.timedelta(48),
#  datetime.timedelta(145),
#  datetime.timedelta(126),
#  datetime.timedelta(583),
#  datetime.timedelta(31),
#  datetime.timedelta(3),
#  datetime.timedelta(960),
#  datetime.timedelta(20),
#  datetime.timedelta(39),
#  datetime.timedelta(708),
#  datetime.timedelta(129),
#  datetime.timedelta(13),
#  datetime.timedelta(1080),
#  datetime.timedelta(1),
#  datetime.timedelta(207),
#  datetime.timedelta(30),
#  datetime.timedelta(931),
#  datetime.timedelta(1310),
#  datetime.timedelta(85),
#  datetime.timedelta(76),
#  datetime.timedelta(215),
#  datetime.timedelta(767),
#  datetime.timedelta(72),
#  datetime.timedelta(141),
#  datetime.timedelta(224),
#  datetime.timedelta(189),
#  datetime.timedelta(105),
#  datetime.timedelta(0),
#  datetime.timedelta(142),
#  datetime.timedelta(257),
#  datetime.timedelta(393),
#  datetime.timedelta(82),
#  datetime.timedelta(1),
#  datetime.timedelta(-6),
#  datetime.timedelta(1),
#  datetime.timedelta(0),
#  datetime.timedelta(0),
#  datetime.timedelta(58),
#  datetime.timedelta(0),
#  datetime.timedelta(0),
#  datetime.timedelta(221),
#  datetime.timedelta(8),
#  datetime.timedelta(-1),
#  datetime.timedelta(160),
#  datetime.timedelta(160),
#  datetime.timedelta(357),
#  datetime.timedelta(116),
#  datetime.timedelta(29),
#  datetime.timedelta(3),
#  datetime.timedelta(0),
#  datetime.timedelta(0),
#  datetime.timedelta(873),
#  datetime.timedelta(190),
#  datetime.timedelta(87),
#  datetime.timedelta(123),
#  datetime.timedelta(178),
#  datetime.timedelta(510),
#  datetime.timedelta(865),
#  datetime.timedelta(133),
#  datetime.timedelta(58),
#  datetime.timedelta(1438),
#  datetime.timedelta(-155)]

# %%
df['스팀발매일이전까지의유튜브등록날짜']=between_Pubdate_UtubeRegister

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름 회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜
# 199         SaintHeiser     2011년     6년          865 days
# 200            Rabbiton     2015년     2년          133 days
# 201  Haydee Interactive     2016년     1년           58 days
# 202   Visiontrick Media     2012년     5년         1438 days
# 203       Caravel Games     2002년    15년         -155 days

# %%
df.groupby('스팀다운로드횟수')['스팀발매일이전까지의유튜브등록날짜'].max()
# Out:
# 스팀다운로드횟수
# 0        881 days
# 1        500 days
# 10      1049 days
# 102       29 days
# 1032     236 days
# 11       197 days
# 11234    138 days
# 1126       0 days
# 117       30 days
# 119       15 days
# 1196     793 days
# 12       873 days
# 122     1007 days
# 13      1557 days
# 1313       0 days
# 133       85 days
# 139      870 days
# 14       172 days
# 15        74 days
# 155      224 days
# 16       888 days
# 17        48 days
# 170      198 days
# 18       865 days
# 181      145 days
# 185      173 days
# 19       807 days
# 1922      74 days
# 2        977 days
# 20       592 days
#            ...
# 54       123 days
# 549      221 days
# 56         6 days
# 57       429 days
# 6          1 days
# 60      1213 days
# 62       357 days
# 63      1005 days
# 639       72 days
# 64       256 days
# 652        3 days
# 67       931 days
# 679      873 days
# 68       133 days
# 69       468 days
# 7        116 days
# 7074     225 days
# 71       658 days
# 74       136 days
# 76       393 days
# 83      1123 days
# 866      637 days
# 88      1015 days
# 89       351 days
# 890       58 days
# 8969     450 days
# 899       67 days
# 9        292 days
# 91        43 days
# 974       24 days
# Name: 스팀발매일이전까지의유튜브등록날짜, Length: 110, dtype: timedelta64[ns]

# %%
df['총다운로드수']=pd.to_numeric(df['스팀다운로드횟수'],errors='ignore')+pd.to_numeric(df['스팀외다운로드 횟수'],errors='ignore')

# %%
df.head()
# Out:
#                                     게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 0                       Little Nightmare  2017-05-09     1196        331
# 1  Bendy and the Ink machine Chapter one  2017-05-09       29       1307
# 2                        The SEXY BRUTAL  2017-05-09      214         14
# 3  Bendy and the Ink machine Chapter two  2017-05-09       89          7
# 4               Ori and the Blind Forest  2017-05-09     4734        713
#
#         스팀발매일    평점       가격   엔진플랫폼    장르     유튜브등록날짜               회사이름  \
# 0  2017-04-28   9.0  25800.0  Unreal    호러  2015-02-25    Tarsier Studios
# 1  2017-04-27   9.0      0.0   Unity    호러  2016-05-11    TheMeatly Games
# 2  2017-04-11   9.0  21000.0   Unity  어드벤쳐  2016-08-19      Tequila Works
# 3  2017-04-27   9.0   6500.0   Unity    호러  2016-05-11    TheMeatly Games
# 4  2015-03-11  10.0  10500.0   Unity    액션  2014-06-09  Moon studios Gmbh
#
#   회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수
# 0     2004년    13년          793 days    1527
# 1    2017년     4개월          351 days    1336
# 2     2009년     8년          235 days     228
# 3    2017년     4개월          351 days      96
# 4     2010년     7년          275 days    5447

# %%
df['매출액']=df['총다운로드수']*df['가격']

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름 회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수         매출액
# 199         SaintHeiser     2011년     6년          865 days      33     72600.0
# 200            Rabbiton     2015년     2년          133 days     961         0.0
# 201  Haydee Interactive     2016년     1년           58 days     959  15344000.0
# 202   Visiontrick Media     2012년     5년         1438 days      46    483000.0
# 203       Caravel Games     2002년    15년         -155 days      36    378000.0

# %%
plt.scatter(df['총다운로드수'],df['매출액'])
plt.show()

# %%
df[df['총다운로드수']>10000]
# Out:
#                                     게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 5   Buy Valiant Hearts: The Great War /   2017-05-09    11234       2431
# 26                                 Limbo  2017-05-14     8969      14892
# 57             RESIDENT EVIL 7 biohazard  2017-05-28     7074       5748
#
#          스팀발매일    평점       가격             엔진플랫폼    장르     유튜브등록날짜      회사이름  \
# 5   2014-01-26  10.0  18500.0  UbiArt Framework  어드벤쳐  2013-09-10   Ubisoft
# 26  2011-08-03  10.0  10500.0     Custom Engine  어드벤쳐  2010-05-10  Playdead
# 57  2017-01-24   9.0  59000.0         RE engine    액션  2016-06-13    CAPCOM
#
#    회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수          매출액
# 5      1986년    31년          138 days   13665  252802500.0
# 26    2006년     11년          450 days   23861  250540500.0
# 57     1979년    38년          225 days   12822  756498000.0

# %%
df[df['매출액']>10000000]
# Out:
#                                      게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 0                        Little Nightmare  2017-05-09     1196        331
# 4                Ori and the Blind Forest  2017-05-09     4734        713
# 5    Buy Valiant Hearts: The Great War /   2017-05-09    11234       2431
# 10                            Machinarium  2017-05-09     1922       1270
# 13                                 Trine3  2017-05-10     2845       1019
# 14                               Syberia3  2017-05-10      354        261
# 24                                  Braid  2017-05-14     3588       2346
# 26                                  Limbo  2017-05-14     8969      14892
# 53                                  Maize  2017-05-27      170        214
# 57              RESIDENT EVIL 7 biohazard  2017-05-28     7074       5748
# 64                      Thimbleweed Park™  2017-05-30      679        274
# 77                        Goodbye Deponia  2017-06-01      866        241
# 81                           King's Quest  2017-06-03     1032        566
# 102                           The Witness  2017-06-07     3347        931
# 115                             Detention  2017-06-07     3200        231
# 140                          SHENZHEN I/O  2017-06-10      899        114
# 201                                Haydee  2017-06-14      890         69
#
#           스팀발매일    평점       가격                      엔진플랫폼     장르     유튜브등록날짜  \
# 0    2017-04-28   9.0  25800.0                     Unreal     호러  2015-02-25
# 4    2015-03-11  10.0  10500.0                      Unity     액션  2014-06-09
# 5    2014-01-26  10.0  18500.0           UbiArt Framework   어드벤쳐  2013-09-10
# 10   2009-10-17   9.0  10000.0                      REBOL   어드벤쳐  2009-08-04
# 13   2015-08-20   6.0  23000.0              Custom Engine     액션  2015-03-02
# 14   2017-04-20   6.0  43000.0                      Unity   어드벤쳐  2015-09-22
# 24   2009-04-11   9.0  16000.0  Microsoft's XNA framework    캐쥬얼  2008-06-08
# 26   2011-08-03  10.0  10500.0              Custom Engine   어드벤쳐  2010-05-10
# 53   2016-12-02   9.0  27000.0                     Unreal   어드벤쳐  2016-05-18
# 57   2017-01-24   9.0  59000.0                  RE engine     액션  2016-06-13
# 64   2017-03-31  10.0  21000.0              Custom Engine   어드벤쳐  2014-11-09
# 77   2013-10-08   9.0  21000.0              Custom Engine   어드벤쳐  2012-01-10
# 81   2015-07-29   9.0  29900.0                     Unreal   어드벤쳐  2014-12-05
# 102  2016-01-26   9.0  42000.0              Custom Engine   어드벤쳐  2013-02-20
# 115  2017-01-13  10.0  13000.0                      Unity     호러  2015-12-11
# 140  2016-11-18  10.0  16000.0                        SDL  시뮬레이션  2016-09-12
# 201  2016-09-27   9.0  16000.0              Custom Engine     액션  2016-07-31
#
#                        회사이름 회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수  \
# 0           Tarsier Studios     2004년    13년          793 days    1527
# 4         Moon studios Gmbh     2010년     7년          275 days    5447
# 5                   Ubisoft     1986년    31년          138 days   13665
# 10           Amanita Design     2003년    14년           74 days    3192
# 13               Frozenbyte    2001년     16년          171 days    3864
# 14                 Microids     1984년    33년          576 days     615
# 24              Number None    2006년     11년          307 days    5934
# 26                 Playdead    2006년     11년          450 days   23861
# 53        Finish Line Games     2013년     4년          198 days     384
# 57                   CAPCOM     1979년    38년          225 days   12822
# 64          Terrible Toybox     2014년     3년          873 days     953
# 77   Daedalic Entertainment     2007년    10년          637 days    1107
# 81                   Sierra     1979년    38년          236 days    1598
# 102            Thekla, Inc-     2009년     8년         1070 days    4278
# 115          RedCandleGames     2015년     2년          399 days    3431
# 140             Zachtronics     2006년    11년           67 days    1013
# 201      Haydee Interactive     2016년     1년           58 days     959
#
#              매출액
# 0     39396600.0
# 4     57193500.0
# 5    252802500.0
# 10    31920000.0
# 13    88872000.0
# 14    26445000.0
# 24    94944000.0
# 26   250540500.0
# 53    10368000.0
# 57   756498000.0
# 64    20013000.0
# 77    23247000.0
# 81    47780200.0
# 102  179676000.0
# 115   44603000.0
# 140   16208000.0
# 201   15344000.0

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=u'총다운로드수',y=u'매출액',data=df)
plt.show()

# %%
dateCount=pd.to_numeric(df['스팀발매일이전까지의유튜브등록날짜'])
dateCount
# Out:
# 0       68515200000000000
# 1       30326400000000000
# 2       20304000000000000
# 3       30326400000000000
# 4       23760000000000000
# 5       11923200000000000
# 6       87696000000000000
# 7          86400000000000
# 8         -86400000000000
# 9        6393600000000000
# 10       6393600000000000
# 11       6480000000000000
# 12       6912000000000000
# 13      14774400000000000
# 14      49766400000000000
# 15        777600000000000
# 16      30326400000000000
# 17      24883200000000000
# 18                      0
# 19       1468800000000000
# 20       9072000000000000
# 21      85449600000000000
# 22      97027200000000000
# 23       2246400000000000
# 24      26524800000000000
# 25      90633600000000000
# 26      38880000000000000
# 27       3110400000000000
# 28      14947200000000000
# 29      43200000000000000
#               ...
# 174        86400000000000
# 175      -518400000000000
# 176        86400000000000
# 177                     0
# 178                     0
# 179      5011200000000000
# 180                     0
# 181                     0
# 182     19094400000000000
# 183       691200000000000
# 184       -86400000000000
# 185     13824000000000000
# 186     13824000000000000
# 187     30844800000000000
# 188     10022400000000000
# 189      2505600000000000
# 190       259200000000000
# 191                     0
# 192                     0
# 193     75427200000000000
# 194     16416000000000000
# 195      7516800000000000
# 196     10627200000000000
# 197     15379200000000000
# 198     44064000000000000
# 199     74736000000000000
# 200     11491200000000000
# 201      5011200000000000
# 202    124243200000000000
# 203    -13392000000000000
# Name: 스팀발매일이전까지의유튜브등록날짜, Length: 204, dtype: int64

# %%
dateCount=dateCount/60/60/24/100000000000*10**2

# %%
dateCount
# Out:
# 0       793.0
# 1       351.0
# 2       235.0
# 3       351.0
# 4       275.0
# 5       138.0
# 6      1015.0
# 7         1.0
# 8        -1.0
# 9        74.0
# 10       74.0
# 11       75.0
# 12       80.0
# 13      171.0
# 14      576.0
# 15        9.0
# 16      351.0
# 17      288.0
# 18        0.0
# 19       17.0
# 20      105.0
# 21      989.0
# 22     1123.0
# 23       26.0
# 24      307.0
# 25     1049.0
# 26      450.0
# 27       36.0
# 28      173.0
# 29      500.0
#         ...
# 174       1.0
# 175      -6.0
# 176       1.0
# 177       0.0
# 178       0.0
# 179      58.0
# 180       0.0
# 181       0.0
# 182     221.0
# 183       8.0
# 184      -1.0
# 185     160.0
# 186     160.0
# 187     357.0
# 188     116.0
# 189      29.0
# 190       3.0
# 191       0.0
# 192       0.0
# 193     873.0
# 194     190.0
# 195      87.0
# 196     123.0
# 197     178.0
# 198     510.0
# 199     865.0
# 200     133.0
# 201      58.0
# 202    1438.0
# 203    -155.0
# Name: 스팀발매일이전까지의유튜브등록날짜, Length: 204, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=dateCount, y=df['총다운로드수'])
plt.show()

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름 회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수         매출액
# 199         SaintHeiser     2011년     6년          865 days      33     72600.0
# 200            Rabbiton     2015년     2년          133 days     961         0.0
# 201  Haydee Interactive     2016년     1년           58 days     959  15344000.0
# 202   Visiontrick Media     2012년     5년         1438 days      46    483000.0
# 203       Caravel Games     2002년    15년         -155 days      36    378000.0

# %%
import re
df['회사존속기간']='2017년'

# %%
df.head()
# Out:
#                                     게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 0                       Little Nightmare  2017-05-09     1196        331
# 1  Bendy and the Ink machine Chapter one  2017-05-09       29       1307
# 2                        The SEXY BRUTAL  2017-05-09      214         14
# 3  Bendy and the Ink machine Chapter two  2017-05-09       89          7
# 4               Ori and the Blind Forest  2017-05-09     4734        713
#
#         스팀발매일    평점       가격   엔진플랫폼    장르     유튜브등록날짜               회사이름  \
# 0  2017-04-28   9.0  25800.0  Unreal    호러  2015-02-25    Tarsier Studios
# 1  2017-04-27   9.0      0.0   Unity    호러  2016-05-11    TheMeatly Games
# 2  2017-04-11   9.0  21000.0   Unity  어드벤쳐  2016-08-19      Tequila Works
# 3  2017-04-27   9.0   6500.0   Unity    호러  2016-05-11    TheMeatly Games
# 4  2015-03-11  10.0  10500.0   Unity    액션  2014-06-09  Moon studios Gmbh
#
#   회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수         매출액
# 0     2004년  2017년          793 days    1527  39396600.0
# 1    2017년   2017년          351 days    1336         0.0
# 2     2009년  2017년          235 days     228   4788000.0
# 3    2017년   2017년          351 days      96    624000.0
# 4     2010년  2017년          275 days    5447  57193500.0

# %%
FoundedDateYear=[]
for index,row in df.iterrows():
    FoundedDateYear.append(re.sub('[^0-9]', '', row['회사초창기설립날짜']))

# %%
type(FoundedDateYear[0])
# Out:
# str

# %%
FoundedDateYear= pd.to_numeric(FoundedDateYear)

# %%
FoundedDateYear
# Out:
# array([2004, 2017, 2009, 2017, 2010, 1986, 2016, 2017, 2016, 2014, 2003,
#        2015, 2015, 2001, 1984, 2017, 2017, 2013, 2017, 2016, 2017, 2014,
#        2012, 2016, 2006, 2011, 2006, 2014, 1989, 2013, 2014, 2012, 2014,
#        2015, 2016, 2015, 2016, 2017, 2016, 2017, 2016, 2016, 2011, 2016,
#        2016, 2016, 2016, 2012, 2012, 2009, 2016, 2015, 2010, 2013, 2013,
#        2015, 2015, 1979, 2015, 1992, 2015, 2015, 2013, 2013, 2014, 2015,
#        2013, 2010, 2016, 2016, 2016, 2013, 2016, 2015, 2014, 2016, 2014,
#        2007, 2014, 2015, 2015, 1979, 2008, 2015, 2014, 2016, 2012, 2014,
#        2012, 2014, 2015, 2015, 2016, 2015, 2016, 2008, 2015, 2016, 2016,
#        2015, 2016, 2008, 2009, 2002, 2016, 2016, 2014, 2013, 2016, 2015,
#        2012, 2013, 2016, 2012, 2014, 2015, 2011, 2016, 2015, 2017, 2016,
#        2016, 2015, 2015, 2013, 2007, 2014, 2015, 2016, 2011, 2008, 2015,
#        2016, 2016, 2013, 2014, 2016, 2016, 2009, 2009, 2006, 1994, 2011,
#        2015, 2014, 2015, 2016, 2016, 2016, 2015, 2015, 2014, 2016, 2016,
#        2012, 2015, 2015, 2014, 2014, 2002, 2012, 2015, 2011, 2014, 2015,
#        2015, 2005, 2015, 2016, 2016, 2015, 2015, 2011, 2015, 2016, 2016,
#        2016, 2016, 2016, 2016, 2016, 2017, 2013, 2014, 2015, 2016, 2016,
#        2014, 2015, 2014, 2017, 2017, 2017, 2010, 2016, 2016, 2016, 2016,
#        2013, 2011, 2015, 2016, 2012, 2002], dtype=int64)

# %%
df['회사초창기설립날짜']=FoundedDateYear

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름  회사초창기설립날짜 회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수  \
# 199         SaintHeiser       2011  2017년          865 days      33
# 200            Rabbiton       2015  2017년          133 days     961
# 201  Haydee Interactive       2016  2017년           58 days     959
# 202   Visiontrick Media       2012  2017년         1438 days      46
# 203       Caravel Games       2002  2017년         -155 days      36
#
#             매출액
# 199     72600.0
# 200         0.0
# 201  15344000.0
# 202    483000.0
# 203    378000.0

# %%
TheseYear=[]
for index,row in df.iterrows():
    TheseYear.append(re.sub('[^0-9]', '', row['회사존속기간']))

# %%
df['회사존속기간']=pd.to_numeric(TheseYear)

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름  회사초창기설립날짜  회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수  \
# 199         SaintHeiser       2011    2017          865 days      33
# 200            Rabbiton       2015    2017          133 days     961
# 201  Haydee Interactive       2016    2017           58 days     959
# 202   Visiontrick Media       2012    2017         1438 days      46
# 203       Caravel Games       2002    2017         -155 days      36
#
#             매출액
# 199     72600.0
# 200         0.0
# 201  15344000.0
# 202    483000.0
# 203    378000.0

# %%
df['회사의존속기간']=df['회사존속기간']-df['회사초창기설립날짜']

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름  회사초창기설립날짜  회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수  \
# 199         SaintHeiser       2011    2017          865 days      33
# 200            Rabbiton       2015    2017          133 days     961
# 201  Haydee Interactive       2016    2017           58 days     959
# 202   Visiontrick Media       2012    2017         1438 days      46
# 203       Caravel Games       2002    2017         -155 days      36
#
#             매출액  회사의존속기간
# 199     72600.0        6
# 200         0.0        2
# 201  15344000.0        1
# 202    483000.0        5
# 203    378000.0       15

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=df['회사의존속기간'], y=df['총다운로드수'])
plt.show()

# %%
df.groupby('엔진플랫폼')['총다운로드수','게임제목'].max()
# Out:
#                            총다운로드수                                  게임제목
# 엔진플랫폼
# Adobe Flash Professional       27                                Wheely
# Adventure Game Engine          13                           Vive le Roi
# Blender Engine                 44                               Caliper
# Construct 2                     9                        Ultimate Solid
# Construct2                      3                         Gaben Kingdom
# Custom Engine               23861                       Warlock's Tower
# Game Maker Studio             961                         Trick & Treat
# MOAI                           71             The Franz Kafka Videogame
# Microsoft's XNA framework    5934                                 Braid
# RE engine                   12822             RESIDENT EVIL 7 biohazard
# REBOL                        3192                           Machinarium
# RPG Maker MV                   66  Crown Champion: Legends of the Arena
# RPG Maker VX                  468             Last Dream: World Unknown
# RPG Maker XP                  100                       Fausts Alptraum
# SDL                          1013                          SHENZHEN I/O
# Stencyl                        36              NEXT JUMP: Shmup Tactics
# TyranoBuilder                  20                       Heart and Seoul
# UbiArt Framework            13665  Buy Valiant Hearts: The Great War /
# Unigine                        61                               Sumoman
# Unity                        5447                                  iREC
# Unreal                       1598                                Winexy
# cocos2d                         9                              Inklings
# wolf rpg mare                 133                             Alicemare
# 질문중 -Steam                   1220                             Zup! Zero
# 질문중 -Youtube                   47                  Remaining in a dream
# 질문중 -steam                   3234                  The Flaws of Gravity
# 질문해야함-누가 질문해놨음                 50             Don't Chat With Strangers

# %%
def peak(x):
    return x.max()

peak(df[df.엔진플랫폼=='Unity'])
# Out:
# 게임제목                               iREC
# 조사날짜                         2017-06-14
# 스팀다운로드횟수                             91
# 스팀외다운로드 횟수                           94
# 스팀발매일                        2017-06-14
# 평점                                   10
# 가격                                43000
# 엔진플랫폼                             Unity
# 장르                                   호러
# 유튜브등록날짜                      2017-06-13
# 회사초창기설립날짜                          2017
# 회사존속기간                             2017
# 스팀발매일이전까지의유튜브등록날짜    1438 days 00:00:00
# 총다운로드수                             5447
# 매출액                         5.71935e+07
# 회사의존속기간                              33
# dtype: object

# %%
df.groupby(df['엔진플랫폼']=='Unity')['총다운로드수','게임제목'].max()
# Out:
#        총다운로드수       게임제목
# 엔진플랫폼
# False   23861  Zup! Zero
# True     5447       iREC

# %%
df.groupby('엔진플랫폼')['총다운로드수','게임제목'].max()
# Out:
#                            총다운로드수                                  게임제목
# 엔진플랫폼
# Adobe Flash Professional       27                                Wheely
# Adventure Game Engine          13                           Vive le Roi
# Blender Engine                 44                               Caliper
# Construct 2                     9                        Ultimate Solid
# Construct2                      3                         Gaben Kingdom
# Custom Engine               23861                       Warlock's Tower
# Game Maker Studio             961                         Trick & Treat
# MOAI                           71             The Franz Kafka Videogame
# Microsoft's XNA framework    5934                                 Braid
# RE engine                   12822             RESIDENT EVIL 7 biohazard
# REBOL                        3192                           Machinarium
# RPG Maker MV                   66  Crown Champion: Legends of the Arena
# RPG Maker VX                  468             Last Dream: World Unknown
# RPG Maker XP                  100                       Fausts Alptraum
# SDL                          1013                          SHENZHEN I/O
# Stencyl                        36              NEXT JUMP: Shmup Tactics
# TyranoBuilder                  20                       Heart and Seoul
# UbiArt Framework            13665  Buy Valiant Hearts: The Great War /
# Unigine                        61                               Sumoman
# Unity                        5447                                  iREC
# Unreal                       1598                                Winexy
# cocos2d                         9                              Inklings
# wolf rpg mare                 133                             Alicemare
# 질문중 -Steam                   1220                             Zup! Zero
# 질문중 -Youtube                   47                  Remaining in a dream
# 질문중 -steam                   3234                  The Flaws of Gravity
# 질문해야함-누가 질문해놨음                 50             Don't Chat With Strangers

# %%
df.tail()
# Out:
#                                    게임제목        조사날짜 스팀다운로드횟수 스팀외다운로드 횟수  \
# 199                            Sig.NULL  2017-06-14       18         15
# 200                       Trick & Treat  2017-06-14       68        893
# 201                              Haydee  2017-06-14      890         69
# 202                            Pavilion  2017-06-14       34         12
# 203  DROD: Gunthro and the Epic Blunder  2017-06-14       16         20
#
#           스팀발매일    평점       가격              엔진플랫폼    장르     유튜브등록날짜  \
# 199  2016-09-27   7.0   2200.0         질문중 -Steam   캐쥬얼  2014-05-16
# 200  2016-09-27  10.0      0.0  Game Maker Studio  어드벤쳐  2016-05-17
# 201  2016-09-27   9.0  16000.0      Custom Engine    액션  2016-07-31
# 202  2016-09-24   8.0  10500.0              Unity  어드벤쳐  2012-10-17
# 203  2012-04-02   8.0  10500.0      Custom Engine  어드벤쳐  2012-09-04
#
#                    회사이름  회사초창기설립날짜  회사존속기간 스팀발매일이전까지의유튜브등록날짜  총다운로드수  \
# 199         SaintHeiser       2011    2017          865 days      33
# 200            Rabbiton       2015    2017          133 days     961
# 201  Haydee Interactive       2016    2017           58 days     959
# 202   Visiontrick Media       2012    2017         1438 days      46
# 203       Caravel Games       2002    2017         -155 days      36
#
#             매출액  회사의존속기간
# 199     72600.0        6
# 200         0.0        2
# 201  15344000.0        1
# 202    483000.0        5
# 203    378000.0       15

# %%
bins=[0,4600,9200,13800,18400,24000]
labels=['정말많이팔림','많이팔림','보통','안팔림','정말안팔림']
labels.reverse()
print(labels)
pd.cut(df.총다운로드수,bins,labels=labels)
# Out:
# ['정말안팔림', '안팔림', '보통', '많이팔림', '정말많이팔림']
# 0       정말안팔림
# 1       정말안팔림
# 2       정말안팔림
# 3       정말안팔림
# 4         안팔림
# 5          보통
# 6       정말안팔림
# 7       정말안팔림
# 8       정말안팔림
# 9       정말안팔림
# 10      정말안팔림
# 11      정말안팔림
# 12      정말안팔림
# 13      정말안팔림
# 14      정말안팔림
# 15      정말안팔림
# 16      정말안팔림
# 17      정말안팔림
# 18      정말안팔림
# 19      정말안팔림
# 20      정말안팔림
# 21      정말안팔림
# 22      정말안팔림
# 23      정말안팔림
# 24        안팔림
# 25      정말안팔림
# 26     정말많이팔림
# 27      정말안팔림
# 28      정말안팔림
# 29      정말안팔림
#         ...
# 174     정말안팔림
# 175     정말안팔림
# 176     정말안팔림
# 177     정말안팔림
# 178     정말안팔림
# 179     정말안팔림
# 180     정말안팔림
# 181     정말안팔림
# 182     정말안팔림
# 183     정말안팔림
# 184     정말안팔림
# 185     정말안팔림
# 186     정말안팔림
# 187     정말안팔림
# 188     정말안팔림
# 189     정말안팔림
# 190     정말안팔림
# 191     정말안팔림
# 192     정말안팔림
# 193     정말안팔림
# 194     정말안팔림
# 195     정말안팔림
# 196     정말안팔림
# 197     정말안팔림
# 198     정말안팔림
# 199     정말안팔림
# 200     정말안팔림
# 201     정말안팔림
# 202     정말안팔림
# 203     정말안팔림
# Name: 총다운로드수, Length: 204, dtype: category
# Categories (5, object): [정말안팔림 < 안팔림 < 보통 < 많이팔림 < 정말많이팔림]

# %%
df['총다운로드수'].max()
# Out:
# 23861

# %%
df['총다운로드수'].min()
# Out:
# 0

# %%
df['총다운로드수'].median()
# Out:
# 40.0

# %%
df.groupby('엔진플랫폼')['매출액','평점'].describe()
# Out:
#                             매출액                                           \
#                           count          mean           std          min
# 엔진플랫폼
# Adobe Flash Professional    1.0  5.940000e+04           NaN      59400.0
# Adventure Game Engine       1.0  5.720000e+04           NaN      57200.0
# Blender Engine              2.0  5.005000e+04  6.611448e+04       3300.0
# Construct 2                 1.0  5.850000e+04           NaN      58500.0
# Construct2                  1.0  6.600000e+03           NaN       6600.0
# Custom Engine              23.0  2.597030e+07  6.348826e+07      85000.0
# Game Maker Studio           6.0  4.228333e+04  5.055731e+04          0.0
# MOAI                        1.0  7.455000e+05           NaN     745500.0
# Microsoft's XNA framework   1.0  9.494400e+07           NaN   94944000.0
# RE engine                   1.0  7.564980e+08           NaN  756498000.0
# REBOL                       1.0  3.192000e+07           NaN   31920000.0
# RPG Maker MV                2.0  4.125000e+04  5.833631e+04          0.0
# RPG Maker VX                3.0  1.706867e+06  2.778781e+06      17600.0
# RPG Maker XP                1.0  0.000000e+00           NaN          0.0
# SDL                         1.0  1.620800e+07           NaN   16208000.0
# Stencyl                     2.0  6.380000e+04  3.422397e+04      39600.0
# TyranoBuilder               1.0  6.600000e+04           NaN      66000.0
# UbiArt Framework            1.0  2.528025e+08           NaN  252802500.0
# Unigine                     1.0  1.098000e+06           NaN    1098000.0
# Unity                      95.0  2.241782e+06  7.863206e+06          0.0
# Unreal                     24.0  4.403370e+06  1.232040e+07          0.0
# cocos2d                     1.0  9.450000e+04           NaN      94500.0
# wolf rpg mare               1.0  4.389000e+05           NaN     438900.0
# 질문중 -Steam                 20.0  6.143025e+05  2.020402e+06          0.0
# 질문중 -Youtube                1.0  5.170000e+04           NaN      51700.0
# 질문중 -steam                  4.0  1.814450e+06  3.533799e+06          0.0
# 질문해야함-누가 질문해놨음              1.0  2.750000e+05           NaN     275000.0
#
#                                                                                \
#                                    25%          50%          75%          max
# 엔진플랫폼
# Adobe Flash Professional       59400.0      59400.0      59400.0      59400.0
# Adventure Game Engine          57200.0      57200.0      57200.0      57200.0
# Blender Engine                 26675.0      50050.0      73425.0      96800.0
# Construct 2                    58500.0      58500.0      58500.0      58500.0
# Construct2                      6600.0       6600.0       6600.0       6600.0
# Custom Engine                 337250.0    1007500.0   10255000.0  250540500.0
# Game Maker Studio               6500.0      26750.0      58025.0     132000.0
# MOAI                          745500.0     745500.0     745500.0     745500.0
# Microsoft's XNA framework   94944000.0   94944000.0   94944000.0   94944000.0
# RE engine                  756498000.0  756498000.0  756498000.0  756498000.0
# REBOL                       31920000.0   31920000.0   31920000.0   31920000.0
# RPG Maker MV                   20625.0      41250.0      61875.0      82500.0
# RPG Maker VX                  103300.0     189000.0    2551500.0    4914000.0
# RPG Maker XP                       0.0          0.0          0.0          0.0
# SDL                         16208000.0   16208000.0   16208000.0   16208000.0
# Stencyl                        51700.0      63800.0      75900.0      88000.0
# TyranoBuilder                  66000.0      66000.0      66000.0      66000.0
# UbiArt Framework           252802500.0  252802500.0  252802500.0  252802500.0
# Unigine                      1098000.0    1098000.0    1098000.0    1098000.0
# Unity                          53000.0     242000.0    1230500.0   57193500.0
# Unreal                         30225.0     129850.0     804775.0   47780200.0
# cocos2d                        94500.0      94500.0      94500.0      94500.0
# wolf rpg mare                 438900.0     438900.0     438900.0     438900.0
# 질문중 -Steam                     41437.5      75300.0     194425.0    9150000.0
# 질문중 -Youtube                   51700.0      51700.0      51700.0      51700.0
# 질문중 -steam                     33000.0      71500.0    1852950.0    7114800.0
# 질문해야함-누가 질문해놨음                275000.0     275000.0     275000.0     275000.0
#
#                              평점                                          \
#                           count       mean       std   min    25%   50%
# 엔진플랫폼
# Adobe Flash Professional    1.0   9.000000       NaN   9.0   9.00   9.0
# Adventure Game Engine       0.0        NaN       NaN   NaN    NaN   NaN
# Blender Engine              1.0   6.000000       NaN   6.0   6.00   6.0
# Construct 2                 0.0        NaN       NaN   NaN    NaN   NaN
# Construct2                  0.0        NaN       NaN   NaN    NaN   NaN
# Custom Engine              21.0   8.333333  1.154701   6.0   8.00   8.0
# Game Maker Studio           4.0   7.750000  1.707825   6.0   6.75   7.5
# MOAI                        1.0   9.000000       NaN   9.0   9.00   9.0
# Microsoft's XNA framework   1.0   9.000000       NaN   9.0   9.00   9.0
# RE engine                   1.0   9.000000       NaN   9.0   9.00   9.0
# REBOL                       1.0   9.000000       NaN   9.0   9.00   9.0
# RPG Maker MV                1.0   9.000000       NaN   9.0   9.00   9.0
# RPG Maker VX                2.0   8.500000  0.707107   8.0   8.25   8.5
# RPG Maker XP                1.0   9.000000       NaN   9.0   9.00   9.0
# SDL                         1.0  10.000000       NaN  10.0  10.00  10.0
# Stencyl                     2.0   7.500000  0.707107   7.0   7.25   7.5
# TyranoBuilder               1.0   6.000000       NaN   6.0   6.00   6.0
# UbiArt Framework            1.0  10.000000       NaN  10.0  10.00  10.0
# Unigine                     1.0   8.000000       NaN   8.0   8.00   8.0
# Unity                      66.0   8.106061  1.097252   5.0   8.00   8.0
# Unreal                     14.0   7.500000  1.224745   5.0   7.00   7.0
# cocos2d                     0.0        NaN       NaN   NaN    NaN   NaN
# wolf rpg mare               1.0   9.000000       NaN   9.0   9.00   9.0
# 질문중 -Steam                 14.0   7.928571  1.141139   6.0   7.00   8.0
# 질문중 -Youtube                1.0   5.000000       NaN   5.0   5.00   5.0
# 질문중 -steam                  3.0   7.666667  1.527525   6.0   7.00   8.0
# 질문해야함-누가 질문해놨음              1.0   5.000000       NaN   5.0   5.00   5.0
#
#
#                              75%   max
# 엔진플랫폼
# Adobe Flash Professional    9.00   9.0
# Adventure Game Engine        NaN   NaN
# Blender Engine              6.00   6.0
# Construct 2                  NaN   NaN
# Construct2                   NaN   NaN
# Custom Engine               9.00  10.0
# Game Maker Studio           8.50  10.0
# MOAI                        9.00   9.0
# Microsoft's XNA framework   9.00   9.0
# RE engine                   9.00   9.0
# REBOL                       9.00   9.0
# RPG Maker MV                9.00   9.0
# RPG Maker VX                8.75   9.0
# RPG Maker XP                9.00   9.0
# SDL                        10.00  10.0
# Stencyl                     7.75   8.0
# TyranoBuilder               6.00   6.0
# UbiArt Framework           10.00  10.0
# Unigine                     8.00   8.0
# Unity                       9.00  10.0
# Unreal                      8.75   9.0
# cocos2d                      NaN   NaN
# wolf rpg mare               9.00   9.0
# 질문중 -Steam                  9.00   9.0
# 질문중 -Youtube                5.00   5.0
# 질문중 -steam                  8.50   9.0
# 질문해야함-누가 질문해놨음              5.00   5.0

# %%
def show(x):
    return x

show(df[df['엔진플랫폼']!='질문중 -steam'])
df[(df.엔진플랫폼 != '질문중 -steam') & (df.엔진플랫폼 != '질문중 -Steam')]
# Out:
#                                                 게임제목        조사날짜 스팀다운로드횟수  \
# 0                                   Little Nightmare  2017-05-09     1196
# 1              Bendy and the Ink machine Chapter one  2017-05-09       29
# 2                                    The SEXY BRUTAL  2017-05-09      214
# 3              Bendy and the Ink machine Chapter two  2017-05-09       89
# 4                           Ori and the Blind Forest  2017-05-09     4734
# 5               Buy Valiant Hearts: The Great War /   2017-05-09    11234
# 6                                          Pinstripe  2017-05-09       88
# 7                                          CLOCKWISE  2017-05-09        6
# 8                                     Jump,Step,Step  2017-05-09        2
# 9                                        Manipulated  2017-05-09       15
# 10                                       Machinarium  2017-05-09     1922
# 11                                      Arctic alive  2017-05-10       41
# 12                                         Conductor  2017-05-10       19
# 13                                            Trine3  2017-05-10     2845
# 14                                          Syberia3  2017-05-10      354
# 15                                      Kindergarten  2017-05-10      249
# 16       Intelligent Design: An Evolutionary Sandbox  2017-05-13        1
# 17                                        Block'hood  2017-05-13      426
# 18                                       Shadow Mist  2017-05-13        9
# 19                                     Gaben Kingdom  2017-05-13        1
# 20                                     Planet RIX-13  2017-05-13        2
# 21                                           Sumoman  2017-05-13       41
# 22                                     Shift Happens  2017-05-13       83
# 23                                      Mortificatio  2017-05-13        5
# 24                                             Braid  2017-05-14     3588
# 25                                    The Crow's Eye  2017-05-14       10
# 26                                             Limbo  2017-05-14     8969
# 27                                         Causality  2017-05-14       14
# 28                                      GIGA WRECKER  2017-05-14      185
# 29                                          Neverout  2017-05-20        1
# ..                                               ...         ...      ...
# 165                            Soulless: Ray Of Hope  2017-06-13       62
# 166                                 Crazy Machines 3  2017-06-13      155
# 168                             Remaining in a dream  2017-06-13       30
# 170                          Proxy - Ultimate Hacker  2017-06-13        5
# 171                                          Kombine  2017-06-13       32
# 172  Red Comrades 2: For the Great Justice. Reloaded  2017-06-13       76
# 173                                            Rubek  2017-06-13       45
# 175                                            Zup!   2017-06-14     3925
# 176                                           Zup! 2  2017-06-14     3043
# 177                                           Zup! 3  2017-06-14     2636
# 178                                           Zup! 4  2017-06-14     1126
# 179                                           Zup! 5  2017-06-14       54
# 180                                     Phantasma VR  2017-06-14        1
# 182                                Predynastic Egypt  2017-06-14      549
# 183                                           ALONE?  2017-06-14       68
# 185                                       Adam Wolfe  2017-06-14       67
# 186                         Adam Wolfe - Season Pass  2017-06-14        5
# 187                                       Beglitched  2017-06-14       62
# 188                                         Inklings  2017-06-14        7
# 189                                   Art Of Gravity  2017-06-14        4
# 191                                            Oik 2  2017-06-14      282
# 193                                     Star Vikings  2017-06-14       12
# 194                                         Patterna  2017-06-14       19
# 195                                      Maze Sounds  2017-06-14       19
# 197                                      God of Word  2017-06-14       32
# 198                                    Security Hole  2017-06-14       36
# 200                                    Trick & Treat  2017-06-14       68
# 201                                           Haydee  2017-06-14      890
# 202                                         Pavilion  2017-06-14       34
# 203               DROD: Gunthro and the Epic Blunder  2017-06-14       16
#
#     스팀외다운로드 횟수       스팀발매일    평점       가격                      엔진플랫폼     장르  \
# 0          331  2017-04-28   9.0  25800.0                     Unreal     호러
# 1         1307  2017-04-27   9.0      0.0                      Unity     호러
# 2           14  2017-04-11   9.0  21000.0                      Unity   어드벤쳐
# 3            7  2017-04-27   9.0   6500.0                      Unity     호러
# 4          713  2015-03-11  10.0  10500.0                      Unity     액션
# 5         2431  2014-01-26  10.0  18500.0           UbiArt Framework   어드벤쳐
# 6           84  2017-04-25   9.0  16000.0                      Unity   어드벤쳐
# 7            0  2017-05-02   NaN   4400.0                     Unreal   어드벤쳐
# 8            1  2017-03-28   NaN   3300.0                     Unreal   어드벤쳐
# 9            6  2017-03-29   8.0   5500.0                      Unity     액션
# 10        1270  2009-10-17   9.0  10000.0                      REBOL   어드벤쳐
# 11           3  2016-01-29   6.0   2200.0             Blender Engine   어드벤쳐
# 12           8  2017-05-02   8.0  10500.0                      Unity     VR
# 13        1019  2015-08-20   6.0  23000.0              Custom Engine     액션
# 14         261  2017-04-20   6.0  43000.0                      Unity   어드벤쳐
# 15           4  2017-04-08   NaN   5500.0                      Unity     고어
# 16           2  2017-05-12   NaN   7500.0                      Unity  시뮬레이션
# 17          40  2016-03-10   9.0  10500.0                      Unity  시뮬레이션
# 18           1  2017-05-11   NaN   5500.0                      Unity   어드벤쳐
# 19           2  2017-05-13   NaN   2200.0                 Construct2     액션
# 20           0  2017-05-13   NaN   3300.0                      Unity   어드벤쳐
# 21          20  2017-03-29   8.0  18000.0                    Unigine   어드벤쳐
# 22          24  2017-02-23   9.0  16000.0                      Unity     액션
# 23          13  2017-02-27   NaN   5500.0                      Unity   어드벤쳐
# 24        2346  2009-04-11   9.0  16000.0  Microsoft's XNA framework    캐쥬얼
# 25          25  2017-03-20   8.0  16000.0                      Unity   어드벤쳐
# 26       14892  2011-08-03  10.0  10500.0              Custom Engine   어드벤쳐
# 27           5  2017-02-02   8.0   4400.0                      Unity    캐쥬얼
# 28          13  2017-02-07   9.0  21000.0                      Unity     액션
# 29           0  2017-05-19   NaN  10500.0                      Unity  시뮬레이션
# ..         ...         ...   ...      ...                        ...    ...
# 165         16  2016-10-19   7.0  10500.0                      Unity   어드벤쳐
# 166         91  2016-10-19   9.0  21000.0              Custom Engine  시뮬레이션
# 168         17  2016-10-18   5.0   1100.0               질문중 -Youtube   어드벤쳐
# 170          1  2016-10-14   NaN   8500.0                      Unity  시뮬레이션
# 171          4  2016-10-15   7.0   1100.0                    Stencyl    캐쥬얼
# 172         19  2016-10-14   9.0   5500.0                      Unity   어드벤쳐
# 173          3  2016-10-14   7.0   3300.0                      Unity    캐쥬얼
# 175        295  2016-10-04   9.0   1100.0                        NaN    캐쥬얼
# 176        192  2016-12-06  10.0   1100.0                        NaN    캐쥬얼
# 177        124  2017-01-12   9.0   1100.0                        NaN    캐쥬얼
# 178         56  2017-02-20   9.0   1100.0                        NaN    캐쥬얼
# 179          1  2017-06-13   8.0   1100.0                        NaN    캐쥬얼
# 180          1  2017-06-13   NaN  21000.0                      Unity     VR
# 182         69  2016-10-10   9.0  10500.0                      Unity     전략
# 183         18  2016-10-11   6.0   3300.0                      Unity     VR
# 185         88  2016-10-07   9.0   6500.0              Custom Engine   어드벤쳐
# 186          0  2016-10-07   NaN  17000.0              Custom Engine   어드벤쳐
# 187         21  2016-10-07   9.0  10500.0                      Unity   어드벤쳐
# 188          2  2016-10-07   NaN  10500.0                    cocos2d     전략
# 189         14  2017-06-14   NaN   1100.0                      Unity    캐쥬얼
# 191         10  2017-03-28   9.0   1100.0                        NaN    캐쥬얼
# 193         12  2016-10-06   8.0  10500.0                      Unity    RPG
# 194          6  2016-10-04   8.0   7500.0                      Unity    캐쥬얼
# 195         10  2016-10-03   6.0   5500.0                     Unreal   어드벤쳐
# 197         17  2016-09-29   8.0   5500.0                      Unity     액션
# 198         94  2016-09-28   8.0  10000.0                      Unity  시뮬레이션
# 200        893  2016-09-27  10.0      0.0          Game Maker Studio   어드벤쳐
# 201         69  2016-09-27   9.0  16000.0              Custom Engine     액션
# 202         12  2016-09-24   8.0  10500.0                      Unity   어드벤쳐
# 203         20  2012-04-02   8.0  10500.0              Custom Engine   어드벤쳐
#
#         유튜브등록날짜                   회사이름  회사초창기설립날짜  회사존속기간 스팀발매일이전까지의유튜브등록날짜  \
# 0    2015-02-25        Tarsier Studios       2004    2017          793 days
# 1    2016-05-11        TheMeatly Games       2017    2017          351 days
# 2    2016-08-19          Tequila Works       2009    2017          235 days
# 3    2016-05-11        TheMeatly Games       2017    2017          351 days
# 4    2014-06-09      Moon studios Gmbh       2010    2017          275 days
# 5    2013-09-10                Ubisoft       1986    2017          138 days
# 6    2014-07-15           Thomas Brush       2016    2017         1015 days
# 7    2017-05-01                    NaN       2017    2017            1 days
# 8    2017-03-29                    NaN       2016    2017           -1 days
# 9    2017-01-14  Wolfray Entertainment       2014    2017           74 days
# 10   2009-08-04         Amanita Design       2003    2017           74 days
# 11   2015-11-15                    NaN       2015    2017           75 days
# 12   2017-02-11               Overflow       2015    2017           80 days
# 13   2015-03-02             Frozenbyte       2001    2017          171 days
# 14   2015-09-22               Microids       1984    2017          576 days
# 15   2017-03-30                    NaN       2017    2017            9 days
# 16   2016-05-26   Pill Bug Interactive       2017    2017          351 days
# 17   2015-05-27   Plethora-Project LLC       2013    2017          288 days
# 18   2017-05-11                    NaN       2017    2017            0 days
# 19   2017-04-26             AAG Studio       2016    2017           17 days
# 20   2017-01-28     9 Eyes Game Studio       2017    2017          105 days
# 21   2014-07-14     Tequilabyte Studio       2014    2017          989 days
# 22   2014-01-27            Klonk Games       2012    2017         1123 days
# 23   2017-02-01        SmartHart Games       2016    2017           26 days
# 24   2008-06-08            Number None       2006    2017          307 days
# 25   2014-05-06      3D2 Entertainment       2011    2017         1049 days
# 26   2010-05-10               Playdead       2006    2017          450 days
# 27   2016-12-28                   Loju       2014    2017           36 days
# 28   2016-08-18         GAME FREAK inc       1989    2017          173 days
# 29   2016-01-05      Setapp Sp- z o-o-       2013    2017          500 days
# ..          ...                    ...        ...     ...               ...
# 165  2016-05-31     Frisky Fatal Games       2015    2017          141 days
# 166  2016-03-09          Fakt Software       2005    2017          224 days
# 168  2016-07-05              Primitive       2016    2017          105 days
# 170  2016-05-25       Ready Play Games       2015    2017          142 days
# 171  2016-02-01                    NaN       2015    2017          257 days
# 172  2015-09-17       Buka Development       2011    2017          393 days
# 173  2016-07-24            Xigma Games       2015    2017           82 days
# 175  2016-10-10            Quiet River       2016    2017           -6 days
# 176  2016-12-05            Quiet River       2016    2017            1 days
# 177  2017-01-12            Quiet River       2016    2017            0 days
# 178  2017-02-20            Quiet River       2016    2017            0 days
# 179  2017-04-16            Quiet River       2016    2017           58 days
# 180  2017-06-13    The Shady Gentlemen       2016    2017            0 days
# 182  2016-03-03        Clarus Victoria       2013    2017          221 days
# 183  2016-10-03   Deceptive Games Ltd.       2014    2017            8 days
# 185  2016-04-30         Mad Head Games       2016    2017          160 days
# 186  2016-04-30         Mad Head Games       2016    2017          160 days
# 187  2015-10-16            Hexecutable       2014    2017          357 days
# 188  2016-06-13        Applepine Games       2015    2017          116 days
# 189  2017-05-16  Hamster On Coke Games       2014    2017           29 days
# 191  2017-03-28                    NaN       2017    2017            0 days
# 193  2014-05-17            Rogue Snail       2010    2017          873 days
# 194  2016-03-28                    NaN       2016    2017          190 days
# 195  2016-07-08           AMIDEA Games       2016    2017           87 days
# 197  2016-04-04        Mega Dwarf Inc.       2016    2017          178 days
# 198  2015-05-07                 AnRaEl       2013    2017          510 days
# 200  2016-05-17               Rabbiton       2015    2017          133 days
# 201  2016-07-31     Haydee Interactive       2016    2017           58 days
# 202  2012-10-17      Visiontrick Media       2012    2017         1438 days
# 203  2012-09-04          Caravel Games       2002    2017         -155 days
#
#      총다운로드수          매출액  회사의존속기간
# 0      1527   39396600.0       13
# 1      1336          0.0        0
# 2       228    4788000.0        8
# 3        96     624000.0        0
# 4      5447   57193500.0        7
# 5     13665  252802500.0       31
# 6       172    2752000.0        1
# 7         6      26400.0        0
# 8         3       9900.0        1
# 9        21     115500.0        3
# 10     3192   31920000.0       14
# 11       44      96800.0        2
# 12       27     283500.0        2
# 13     3864   88872000.0       16
# 14      615   26445000.0       33
# 15      253    1391500.0        0
# 16        3      22500.0        0
# 17      466    4893000.0        4
# 18       10      55000.0        0
# 19        3       6600.0        1
# 20        2       6600.0        0
# 21       61    1098000.0        3
# 22      107    1712000.0        5
# 23       18      99000.0        1
# 24     5934   94944000.0       11
# 25       35     560000.0        6
# 26    23861  250540500.0       11
# 27       19      83600.0        3
# 28      198    4158000.0       28
# 29        1      10500.0        4
# ..      ...          ...      ...
# 165      78     819000.0        2
# 166     246    5166000.0       12
# 168      47      51700.0        1
# 170       6      51000.0        2
# 171      36      39600.0        2
# 172      95     522500.0        6
# 173      48     158400.0        2
# 175    4220    4642000.0        1
# 176    3235    3558500.0        1
# 177    2760    3036000.0        1
# 178    1182    1300200.0        1
# 179      55      60500.0        1
# 180       2      42000.0        1
# 182     618    6489000.0        4
# 183      86     283800.0        3
# 185     155    1007500.0        1
# 186       5      85000.0        1
# 187      83     871500.0        3
# 188       9      94500.0        2
# 189      18      19800.0        3
# 191     292     321200.0        0
# 193      24     252000.0        7
# 194      25     187500.0        1
# 195      29     159500.0        1
# 197      49     269500.0        1
# 198     130    1300000.0        4
# 200     961          0.0        2
# 201     959   15344000.0        1
# 202      46     483000.0        5
# 203      36     378000.0       15
#
# [180 rows x 17 columns]

# %%
print(df[(df['엔진플랫폼']=='Unity')]['총다운로드수'].describe())
df[(df['엔진플랫폼']=='Unreal')]['총다운로드수'].describe()
#df.groupby(df['엔진플랫폼']=='Unity')['총다운로드수','게임제목'].max()
# Out:
# count      95.000000
# mean      247.178947
# std       771.857568
# min         0.000000
# 25%        18.000000
# 50%        35.000000
# 75%       105.000000
# max      5447.000000
# Name: 총다운로드수, dtype: float64
# count      24.000000
# mean      171.708333
# std       435.275872
# min         1.000000
# 25%         6.000000
# 50%        30.500000
# 75%        59.750000
# max      1598.000000
# Name: 총다운로드수, dtype: float64

# %%
df.sort_values(by=['회사초창기설립날짜'],ascending=True)
# Out:
#                                                   게임제목        조사날짜 스팀다운로드횟수  \
# 0                                     Little Nightmare  2017-05-09     1196
# 1                Bendy and the Ink machine Chapter one  2017-05-09       29
# 2                                      The SEXY BRUTAL  2017-05-09      214
# 3                Bendy and the Ink machine Chapter two  2017-05-09       89
# 4                             Ori and the Blind Forest  2017-05-09     4734
# 5                 Buy Valiant Hearts: The Great War /   2017-05-09    11234
# 6                                            Pinstripe  2017-05-09       88
# 7                                            CLOCKWISE  2017-05-09        6
# 8                                       Jump,Step,Step  2017-05-09        2
# 9                                          Manipulated  2017-05-09       15
# 10                                         Machinarium  2017-05-09     1922
# 11                                        Arctic alive  2017-05-10       41
# 12                                           Conductor  2017-05-10       19
# 13                                              Trine3  2017-05-10     2845
# 16         Intelligent Design: An Evolutionary Sandbox  2017-05-13        1
# 14                                            Syberia3  2017-05-10      354
# 15                                        Kindergarten  2017-05-10      249
# 17                                          Block'hood  2017-05-13      426
# 18                                         Shadow Mist  2017-05-13        9
# 19                                       Gaben Kingdom  2017-05-13        1
# 20                                       Planet RIX-13  2017-05-13        2
# 21                                             Sumoman  2017-05-13       41
# 22                                       Shift Happens  2017-05-13       83
# 23                                        Mortificatio  2017-05-13        5
# 24                                               Braid  2017-05-14     3588
# 25                                      The Crow's Eye  2017-05-14       10
# 26                                               Limbo  2017-05-14     8969
# 27                                           Causality  2017-05-14       14
# 31                          Bokida - Heartfelt Reunion  2017-05-20       19
# 30   Grav|Lab - Gravitational Testing Facility & Ob...  2017-05-20       20
# ..                                                 ...         ...      ...
# 143                                                VOI  2017-06-10      181
# 144                                   Animated Puzzles  2017-06-11       21
# 138                                        Ittle Dew 2  2017-06-10       69
# 146                                 Constricting Cubes  2017-06-11        2
# 145                    Gravity Shot : Planet Destroyer  2017-06-11        2
# 158                                        Redirection  2017-06-11       67
# 156                                              LUXIS  2017-06-11        5
# 154                                    Crazy Sapper 3D  2017-06-11        4
# 153                                     Ultimate Solid  2017-06-11        3
# 155                                       Death's Life  2017-06-11       24
# 151                         Social Interaction Trainer  2017-06-11       40
# 150                                    Heart and Seoul  2017-06-11       14
# 149        Unforgiven: Missing Memories - Child's Play  2017-06-11       11
# 148                             Dungeon Of Doom Puzzle  2017-06-11        2
# 147                                         The Survey  2017-06-11      102
# 152                       Miniature - The Story Puzzle  2017-06-11       25
# 197                                        God of Word  2017-06-14       32
# 201                                             Haydee  2017-06-14      890
# 200                                      Trick & Treat  2017-06-14       68
# 199                                           Sig.NULL  2017-06-14       18
# 198                                      Security Hole  2017-06-14       36
# 196                                           Recursed  2017-06-14       54
# 190                                                Oik  2017-06-14      652
# 194                                           Patterna  2017-06-14       19
# 193                                       Star Vikings  2017-06-14       12
# 192                                       Wild Unknown  2017-06-14        3
# 191                                              Oik 2  2017-06-14      282
# 202                                           Pavilion  2017-06-14       34
# 195                                        Maze Sounds  2017-06-14       19
# 203                 DROD: Gunthro and the Epic Blunder  2017-06-14       16
#
#     스팀외다운로드 횟수       스팀발매일    평점       가격                      엔진플랫폼     장르  \
# 0          331  2017-04-28   9.0  25800.0                     Unreal     호러
# 1         1307  2017-04-27   9.0      0.0                      Unity     호러
# 2           14  2017-04-11   9.0  21000.0                      Unity   어드벤쳐
# 3            7  2017-04-27   9.0   6500.0                      Unity     호러
# 4          713  2015-03-11  10.0  10500.0                      Unity     액션
# 5         2431  2014-01-26  10.0  18500.0           UbiArt Framework   어드벤쳐
# 6           84  2017-04-25   9.0  16000.0                      Unity   어드벤쳐
# 7            0  2017-05-02   NaN   4400.0                     Unreal   어드벤쳐
# 8            1  2017-03-28   NaN   3300.0                     Unreal   어드벤쳐
# 9            6  2017-03-29   8.0   5500.0                      Unity     액션
# 10        1270  2009-10-17   9.0  10000.0                      REBOL   어드벤쳐
# 11           3  2016-01-29   6.0   2200.0             Blender Engine   어드벤쳐
# 12           8  2017-05-02   8.0  10500.0                      Unity     VR
# 13        1019  2015-08-20   6.0  23000.0              Custom Engine     액션
# 16           2  2017-05-12   NaN   7500.0                      Unity  시뮬레이션
# 14         261  2017-04-20   6.0  43000.0                      Unity   어드벤쳐
# 15           4  2017-04-08   NaN   5500.0                      Unity     고어
# 17          40  2016-03-10   9.0  10500.0                      Unity  시뮬레이션
# 18           1  2017-05-11   NaN   5500.0                      Unity   어드벤쳐
# 19           2  2017-05-13   NaN   2200.0                 Construct2     액션
# 20           0  2017-05-13   NaN   3300.0                      Unity   어드벤쳐
# 21          20  2017-03-29   8.0  18000.0                    Unigine   어드벤쳐
# 22          24  2017-02-23   9.0  16000.0                      Unity     액션
# 23          13  2017-02-27   NaN   5500.0                      Unity   어드벤쳐
# 24        2346  2009-04-11   9.0  16000.0  Microsoft's XNA framework    캐쥬얼
# 25          25  2017-03-20   8.0  16000.0                      Unity   어드벤쳐
# 26       14892  2011-08-03  10.0  10500.0              Custom Engine   어드벤쳐
# 27           5  2017-02-02   8.0   4400.0                      Unity    캐쥬얼
# 31           6  2017-05-17   NaN  19000.0                      Unity   어드벤쳐
# 30           2  2017-05-18   NaN  21000.0                      Unity     VR
# ..         ...         ...   ...      ...                        ...    ...
# 143         22  2016-11-07   9.0   1100.0                 질문중 -Steam    캐쥬얼
# 144          6  2016-12-06   8.0  10500.0              Custom Engine    캐쥬얼
# 138         13  2016-11-15   9.0  21000.0                      Unity   어드벤쳐
# 146          4  2016-11-08   NaN   3300.0                     Unreal     VR
# 145          0  2016-11-10   NaN   2200.0                      Unity  시뮬레이션
# 158         25  2016-10-25   9.0   8500.0              Custom Engine    캐쥬얼
# 156         21  2016-10-26   NaN   5500.0                      Unity     액션
# 154          8  2016-10-27   NaN   5500.0                      Unity    캐쥬얼
# 153          6  2016-10-27   NaN   6500.0                Construct 2   어드벤쳐
# 155          3  2016-10-26   6.0   3300.0                      Unity    캐쥬얼
# 151          4  2016-11-03   5.0   5500.0                      Unity    캐쥬얼
# 150          6  2016-11-01   6.0   3300.0              TyranoBuilder    캐쥬얼
# 149          1  2016-11-01   8.0   7500.0                     Unreal     VR
# 148          2  2016-10-29   NaN   2200.0                 질문중 -Steam   어드벤쳐
# 147         11  2016-10-27   7.0   5500.0                      Unity     호러
# 152         13  2016-10-28   5.0   5500.0                     Unreal    캐쥬얼
# 197         17  2016-09-29   8.0   5500.0                      Unity     액션
# 201         69  2016-09-27   9.0  16000.0              Custom Engine     액션
# 200        893  2016-09-27  10.0      0.0          Game Maker Studio   어드벤쳐
# 199         15  2016-09-27   7.0   2200.0                 질문중 -Steam    캐쥬얼
# 198         94  2016-09-28   8.0  10000.0                      Unity  시뮬레이션
# 196          9  2016-10-01   9.0   8500.0                 질문중 -Steam   어드벤쳐
# 190         20  2017-02-15   9.0   1100.0                 질문중 -Steam    캐쥬얼
# 194          6  2016-10-04   8.0   7500.0                      Unity    캐쥬얼
# 193         12  2016-10-06   8.0  10500.0                      Unity    RPG
# 192          2  2017-03-06   NaN  10500.0                 질문중 -Steam   어드벤쳐
# 191         10  2017-03-28   9.0   1100.0                        NaN    캐쥬얼
# 202         12  2016-09-24   8.0  10500.0                      Unity   어드벤쳐
# 195         10  2016-10-03   6.0   5500.0                     Unreal   어드벤쳐
# 203         20  2012-04-02   8.0  10500.0              Custom Engine   어드벤쳐
#
#         유튜브등록날짜                            회사이름  회사초창기설립날짜  회사존속기간  \
# 0    2015-02-25                 Tarsier Studios       1979    2017
# 1    2016-05-11                 TheMeatly Games       1979    2017
# 2    2016-08-19                   Tequila Works       1984    2017
# 3    2016-05-11                 TheMeatly Games       1986    2017
# 4    2014-06-09               Moon studios Gmbh       1989    2017
# 5    2013-09-10                         Ubisoft       1992    2017
# 6    2014-07-15                    Thomas Brush       1994    2017
# 7    2017-05-01                             NaN       2001    2017
# 8    2017-03-29                             NaN       2002    2017
# 9    2017-01-14           Wolfray Entertainment       2002    2017
# 10   2009-08-04                  Amanita Design       2002    2017
# 11   2015-11-15                             NaN       2003    2017
# 12   2017-02-11                        Overflow       2004    2017
# 13   2015-03-02                      Frozenbyte       2005    2017
# 16   2016-05-26            Pill Bug Interactive       2006    2017
# 14   2015-09-22                        Microids       2006    2017
# 15   2017-03-30                             NaN       2006    2017
# 17   2015-05-27            Plethora-Project LLC       2007    2017
# 18   2017-05-11                             NaN       2007    2017
# 19   2017-04-26                      AAG Studio       2008    2017
# 20   2017-01-28              9 Eyes Game Studio       2008    2017
# 21   2014-07-14              Tequilabyte Studio       2008    2017
# 22   2014-01-27                     Klonk Games       2008    2017
# 23   2017-02-01                 SmartHart Games       2009    2017
# 24   2008-06-08                     Number None       2009    2017
# 25   2014-05-06               3D2 Entertainment       2009    2017
# 26   2010-05-10                        Playdead       2009    2017
# 27   2016-12-28                            Loju       2009    2017
# 31   2015-10-28            Rice Cooker Republic       2010    2017
# 30   2015-10-04                    Mark Schramm       2010    2017
# ..          ...                             ...        ...     ...
# 143  2016-06-15                  Yunus Ayyildiz       2016    2017
# 144  2016-08-02                          Mexond       2016    2017
# 138  2015-08-05                        Ludosity       2016    2017
# 146  2016-10-08                          D-W-S-       2016    2017
# 145  2015-04-07                Drunk Animations       2016    2017
# 158  2014-04-08                Daniel Ratcliffe       2016    2017
# 156  2016-04-02                     Dumbfounded       2016    2017
# 154  2013-11-12                      Aratog LLC       2016    2017
# 153  2016-10-14  What The Fantastic Games Group       2016    2017
# 155  2016-10-25                      Umbu Games       2016    2017
# 151  2014-11-26              Ryan Jake Lambourn       2016    2017
# 150  2016-09-23     Sapphire Dragon Productions       2016    2017
# 149  2016-10-12             Default Interactive       2016    2017
# 148  2014-03-14                       Codespace       2016    2017
# 147  2016-10-24                   Robert Gammon       2016    2017
# 152  2016-06-21                  purpleElephant       2016    2017
# 197  2016-04-04                 Mega Dwarf Inc.       2017    2017
# 201  2016-07-31              Haydee Interactive       2017    2017
# 200  2016-05-17                        Rabbiton       2017    2017
# 199  2014-05-16                     SaintHeiser       2017    2017
# 198  2015-05-07                          AnRaEl       2017    2017
# 196  2016-05-31                             NaN       2017    2017
# 190  2017-02-12                             NaN       2017    2017
# 194  2016-03-28                             NaN       2017    2017
# 193  2014-05-17                     Rogue Snail       2017    2017
# 192  2017-03-06                             NaN       2017    2017
# 191  2017-03-28                             NaN       2017    2017
# 202  2012-10-17               Visiontrick Media       2017    2017
# 195  2016-07-08                    AMIDEA Games       2017    2017
# 203  2012-09-04                   Caravel Games       2017    2017
#
#     스팀발매일이전까지의유튜브등록날짜  총다운로드수          매출액  회사의존속기간
# 0            793 days    1527   39396600.0       13
# 1            351 days    1336          0.0        0
# 2            235 days     228    4788000.0        8
# 3            351 days      96     624000.0        0
# 4            275 days    5447   57193500.0        7
# 5            138 days   13665  252802500.0       31
# 6           1015 days     172    2752000.0        1
# 7              1 days       6      26400.0        0
# 8             -1 days       3       9900.0        1
# 9             74 days      21     115500.0        3
# 10            74 days    3192   31920000.0       14
# 11            75 days      44      96800.0        2
# 12            80 days      27     283500.0        2
# 13           171 days    3864   88872000.0       16
# 16           351 days       3      22500.0        0
# 14           576 days     615   26445000.0       33
# 15             9 days     253    1391500.0        0
# 17           288 days     466    4893000.0        4
# 18             0 days      10      55000.0        0
# 19            17 days       3       6600.0        1
# 20           105 days       2       6600.0        0
# 21           989 days      61    1098000.0        3
# 22          1123 days     107    1712000.0        5
# 23            26 days      18      99000.0        1
# 24           307 days    5934   94944000.0       11
# 25          1049 days      35     560000.0        6
# 26           450 days   23861  250540500.0       11
# 27            36 days      19      83600.0        3
# 31           567 days      25     475000.0        5
# 30           592 days      22     462000.0        3
# ..                ...     ...          ...      ...
# 143          145 days     203     223300.0        2
# 144          126 days      27     283500.0        3
# 138          468 days      82    1722000.0        8
# 146           31 days       6      19800.0        1
# 145          583 days       2       4400.0        2
# 158          931 days      92     782000.0        3
# 156          207 days      26     143000.0        2
# 154         1080 days      12      66000.0        5
# 153           13 days       9      58500.0        1
# 155            1 days      27      89100.0        2
# 151          708 days      44     242000.0        3
# 150           39 days      20      66000.0        2
# 149           20 days      12      90000.0        2
# 148          960 days       4       8800.0        1
# 147            3 days     113     621500.0        1
# 152          129 days      38     209000.0        1
# 197          178 days      49     269500.0        1
# 201           58 days     959   15344000.0        1
# 200          133 days     961          0.0        2
# 199          865 days      33      72600.0        6
# 198          510 days     130    1300000.0        4
# 196          123 days      63     535500.0        1
# 190            3 days     672     739200.0        0
# 194          190 days      25     187500.0        1
# 193          873 days      24     252000.0        7
# 192            0 days       5      52500.0        0
# 191            0 days     292     321200.0        0
# 202         1438 days      46     483000.0        5
# 195           87 days      29     159500.0        1
# 203         -155 days      36     378000.0       15
#
# [204 rows x 17 columns]

# %%
df.회사초창기설립날짜.value_counts()
# Out:
# 2016    58
# 2015    43
# 2014    24
# 2017    14
# 2013    14
# 2012    11
# 2011     8
# 2009     5
# 2010     4
# 2008     4
# 2002     3
# 2006     3
# 2007     2
# 1979     2
# 2005     1
# 2004     1
# 2003     1
# 2001     1
# 1994     1
# 1992     1
# 1989     1
# 1986     1
# 1984     1
# Name: 회사초창기설립날짜, dtype: int64
